# %% [raw]
# Then one calls, for example, np.arange, np.zeros, np.pi, plt.figure, plt.plot, plt.show, etc. Use the pyplot interface for creating figures, and then use the object methods for the rest:

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2, 100)

line1, = plt.plot(x, x, label='linear')
line1.set_dashes([10, 2])
line1.set_dash_capstyle('round')
line1.set_dash_joinstyle('round')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# one dimension plot:

# %%
import numpy as np
import matplotlib as mlb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

np.random.seed(1000)
data = np.random.standard_normal(25)
plt.plot(data.cumsum(), color='g', lw=0.5)
plt.plot(data.cumsum(), 'm.')
plt.grid(True)
plt.legend(['a simple legend'])
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('Cumsum Plot')
plt.xlim(-1, 25)
plt.ylim(np.min(data.cumsum()) - 1, 
         np.max(data.cumsum()) + 1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 1000) #linspace(start, end, num of elements)
y1 = np.sin(x)
y2 = np.cos(x**2)
plt.figure(figsize=(8, 4))
plt.plot(x, y1, 'r', lw=1.5, label='y=sin(x)')
plt.plot(x, y2, 'b--', label='y=cos(x^2)')
plt.axis('scaled')
plt.ylim(-1.2, 1.2)
plt.xlabel('time(s)')
plt.ylabel('volt')
plt.title('time-volt')
plt.legend(loc=0)
plt.show()

# %%
import matplotlib.pyplot as plt

for idx, color in enumerate('rgbyck'):
    plt.subplot(321+idx, axisbg=color)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn

#assign number/string to argument of figure method: num=
#will be held in name attribute
#if number: create new figure or activate existed figure
#if string: set to figure's title
#f1 = plt.figure(num='one')
#f2 = plt.figure(num='two') # need to be tested
f1 = plt.figure(1)
f2 = plt.figure(2)
ax1 = plt.subplot(211)
ax2 = plt.subplot(212)

x = np.linspace(0, 3, 100)
for i in np.arange(5):
    plt.figure(1)
    plt.plot(x, np.exp((i*x)/3))
    plt.sca(ax1)
    plt.plot(x, np.sin(i*x))
    plt.sca(ax2)
    plt.plot(x, np.cos(i*x))
plt.show()

# %%
import numpy as np

np.random.seed(1000)
y = np.random.standard_normal((20, 2)).cumsum(axis=0)
print(dir(y))
print(y)
# Out:
# ['T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_interface__', '__array_prepare__', '__array_priority__', '__array_struct__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshif
# ...

# %%
import numpy as np
import matplotlib as mlb
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(1000)
data = np.random.standard_normal((20,2)).cumsum(axis=0)
data[:, 0] *= 100
fig, ax1 = plt.subplots(figsize=(10,4))
plt.plot(data[:, 0], 'r', lw=0.5, label='line one')
plt.ylabel('value 1st')
plt.legend(loc=2)
ax2 = ax1.twinx()
plt.plot(data[:, 1], lw=1.0, label='line two')
plt.grid(True)
legend = plt.legend(loc=4)
legend.get_frame().set_facecolor('#00FFCC')
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 2nd')
plt.title('Cumsum Plot')
#plt.xlim(-1, 25)
#plt.ylim(np.min(data.cumsum()) - 1, 
#         np.max(data.cumsum()) + 1)
plt.show()

# %%
import numpy as np
import matplotlib as mlb
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(1000)
data = np.random.standard_normal((20,2)).cumsum(axis=0)
data[:, 0] *= 100
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.plot(data[:, 0], 'r', lw=0.5, label='1st')
plt.grid(True)
plt.axis('tight')
plt.ylabel('value')
plt.legend(loc=0)
plt.title('1st Data Set')
plt.subplot(122)
plt.bar(np.arange(len(data)), data[:, 1], width=0.5, label='2nd')
plt.grid(True)
legend = plt.legend(loc=0)
legend.get_frame().set_facecolor('#00FFCC')
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('2nd Data Set')
#plt.xlim(-1, 25)
#plt.ylim(np.min(data.cumsum()) - 1, 
#         np.max(data.cumsum()) + 1)
plt.savefig('/Users/zuoyangxu/Downloads/test.png')
plt.show()

# %%
stat_date = {'11-21', '11-22', '11-23', '11-24', '11-25', '11-26', '11-27'}
type(stat_date)
# Out:
# set

# %%
import numpy as np
import matplotlib as mlb
import matplotlib.pyplot as plt
# %matplotlib inline

stat_date = ['11-21', '11-22', '11-23', '11-24', '11-25', '11-26', '11-27']
register = [67, 83, 59, 33, 43, 34, 44]
sh_open_account = [36, 58, 50, 24, 23, 21, 19]
stock_user_activate = [86, 56, 54, 35, 41, 68, 50]
stock_user_bindcard = [31, 44, 33, 34, 21, 7, 12]

plt.figure(figsize=(10,4))
plt.suptitle('user stat')

plt.subplot(221)
plt.plot(register, 'b', lw=0.5, label='register user')
plt.xticks(np.arange(len(stat_date)), stat_date)
plt.grid(True)
#plt.axis('scaled')
plt.xlabel('date')
plt.ylabel('user num')
plt.legend(loc=0)
#legend = plt.legend(loc=0)
#legend.get_frame().set_facecolor('#00FFCC')
#plt.title('register users for the week')
#plt.subplot(122)
#plt.savefig('/Users/zuoyangxu/Downloads/test.png')

plt.subplot(222)
plt.plot(sh_open_account, 'b', lw=0.5, label='sh new user')
plt.xticks(np.arange(len(stat_date)), stat_date)
plt.grid(True)
plt.xlabel('date')
plt.ylabel('user num')
plt.legend(loc=0)
#plt.title('new user of shanghai bank')

plt.subplot(212)
plt.plot(stock_user_activate, 'b', lw=0.5, label='new active stock user')
plt.plot(stock_user_bindcard, 'r', lw=0.5, label='new bindcard stock user')
plt.xticks(np.arange(len(stat_date)), stat_date)
plt.xticks(np.arange(len(stat_date)), stat_date)
plt.grid(True)
plt.xlabel('date')
plt.ylabel('user num')
plt.legend(loc=0)
#plt.title('new activate stock user')

plt.show()

# %%
import numpy as np
import matplotlib as mlb
import matplotlib.pyplot as plt
# %matplotlib inline

channel = ['appstore', 'huawei', 'yingyongbao',
           'xiaomi', 'w.others']
register = [14, 8, 4, 3, 2]
sh_open_account = [4, 3, 3, 4, 3]
bind_card = [15, 3, 2, 1, 9]
first_invest = [2, 2, 3, 2, 0]
y_pos = np.arange(len(channel))

plt.figure(figsize=(10,4))
plt.suptitle('user stat by channel')

plt.subplot(221)
plt.barh(y_pos, register, color='b', lw=0.5, label='register user')
plt.yticks(y_pos, channel)
#plt.xlabel('channel')
plt.ylabel('user num')
plt.xlim(0, np.max(register)*3/2)

plt.subplot(222)
plt.barh(y_pos, sh_open_account, color='b', lw=0.5, label='sh open account user')
plt.yticks(y_pos, channel)
#plt.xlabel('channel')
#plt.ylabel('user num')
plt.xlim(0, np.max(sh_open_account)*3/2)

plt.subplot(223)
plt.barh(y_pos, bind_card, color='b', lw=0.5, label='bind card user')
plt.yticks(y_pos, channel)
plt.xlabel('channel')
plt.ylabel('user num')
plt.xlim(0, np.max(bind_card)*3/2)

plt.subplot(224)
plt.barh(y_pos, first_invest, color='b', lw=0.5, label='first invest user')
plt.yticks(y_pos, channel)
plt.xlabel('channel')
#plt.ylabel('user num')
plt.xlim(0, np.max(first_invest)*3/2)

plt.show()

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)
ax.plot([1, 2, 3])
ax.set_title('hi mom')
ax.grid(True)
ax.set_xlabel('time')
ax.set_ylabel('volts')
canvas.print_figure('test')

# %% [raw]
# multi bar chart; stack bar chart; back to back bar chart

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = [u'SimHei']
mpl.rcParams['axes.unicode_minus'] = False
data = np.random.randint(1, 5, [3, 4])
print(data)
index = np.arange(data.shape[1])
print(index)
color_index = ['r', 'g', 'b']
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize = (5, 12))
# alpha越小越透明
legends = ['red', 'green', 'blue']
for i in range(data.shape[0]):
	ax1.bar(index + i*.25 + .1, data[i], width = .25, label=legends[i], color = color_index[i],\
	alpha = .1)
# bottom表示y值起点，默认为None
for i in range(data.shape[0]):
	ax2.bar(index + .25, data[i], width = .5, color = color_index[i],\
	bottom = np.sum(data[:i], axis = 0), alpha = .7)
ax3.barh(index, data[0], color = 'r', alpha = .5)
ax3.barh(index, -data[1], color = 'b', alpha = .5)
ax1.legend()
plt.show()
plt.savefig('complex_bar_chart')
# Out:
# [[4 2 1 1]
#  [2 1 1 4]
#  [2 2 4 1]]
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

data = np.random.standard_normal((1000, 2))
c = np.random.randint(0, 10, len(data))
plt.scatter(data[:, 0], data[:, 1], c=c, marker='o')
plt.colorbar()
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# ax2.boxplot(data)

plt.show()

# %%
import datetime

day = datetime.date(2017, 1, 31) - datetime.timedelta(days=29)
print(day.strftime('%Y-%m-%d'))
# Out:
# 2017-01-02

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

data = [[2, 1, 1, 4], [2, 2, 4, 1], [3, 3, 5, 1]]
colors = ['steelblue', 'lightgrey', 'orange']
xticks = ['a', 'b', 'c', 'd', 'e']
for i, item in enumerate(data):
    plt.bar(np.arange(len(item))+i*.15+.2, item, width=.15, linewidth=.1, color=colors[i])
#plt.xticks(np.arange(len(xticks)), xticks)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

#data = ['1', '2', '3', '4', '5']
data = [1, 2, 3, 4, 5]
plt.bar(range(5), data)
plt.show()

# %%
int(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-3f3b1d3c7325> in <module>()
# ----> 1 int(None)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

data = [4, 2, 1, 1]
colors = ['r', 'g', 'b']
xticks = ['a', 'b', 'c', 'd']
plt.barh(range(len(data)), data, color='r', align='center')
plt.yticks(np.arange(len(xticks)), xticks)
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = ''
with open('/home/xuzuoyang/jason.txt', 'r') as f:
    text = f.read()

wordcloud = WordCloud().generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import jieba.analyse
import matplotlib.pyplot as plt
from wordcloud import WordCloud

with open('/home/xuzuoyang/jay.txt', 'r') as f:
    text = f.read()
    text = ' '.join(jieba.cut(text))
    jieba.analyse.set_stop_words('/home/xuzuoyang/stopwords.txt')
    tags=jieba.analyse.extract_tags(text, topK = 50, withWeight = False, allowPOS = ())
    # sentence:待提取的文本。
    # topK:返回几个 TF/IDF 权重最大的关键词，默认值为20。
    # withWeight:是否一并返回关键词权重值，默认值为False。
    # allowPOS:仅包括指定词性的词，默认值为空，即不进行筛选。
    print(tags)

wordcloud = WordCloud('/home/xuzuoyang/Downloads/simsun.ttf').generate(' '.join(tags))

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ['周杰伦', '跳转', '专辑', '2015', '台湾', '2007', '音乐', '电影', '12', '昆凌', '03', '11', '06', '02', '2014', '2006', '吴宗宪', '歌曲', '金曲奖', '2016', 'Jay', '2005', '04', '10', '中文', '周董', '最佳', '编辑', '2010', '2011', '2012', '中国', '香港', '大陆', '大奖', '2008', '22', '英文', '上映', '01', '2003', '29', '2004', '头文字', '唱片', '07', '范特西', '05', 'Chou', '2013']

# %%
import re
import jieba
import pymysql
import matplotlib.pyplot as plt
from wordcloud import WordCloud


db = pymysql.connect(host='localhost',
    db='crawler',
    user='root',
    passwd='584224',
    charset='utf8',
    use_unicode=True)
cursor = db.cursor()

comments = {}
try:
    sql = 'select movie_id, comment_content from comments group by movie_id, comment_content'
    cursor.execute(sql)
    results = cursor.fetchall()
    for row in results:
        movie_id, comment = row[0], row[1]
        if movie_id in comments.keys():
            comments[movie_id].append(comment)
        else:
            comments[movie_id] = list()
except Exception as e:
    print('Exception!')
    print(e)
finally:
    db.close()

with open('/home/xuzuoyang/stopwords.txt') as file:
    stopwords = file.read().split('\n')
    
for movie_id in comments.keys():
    comment = ''.join(comments[movie_id])
    pattern = re.compile(r'[\u4e00-\u9fa5]+')
    filterdata = re.findall(pattern, comment)
    cleaned_comment = ''.join(filterdata)
    
#     jieba.analyse.set_stop_words('/home/xuzuoyang/stopwords.txt')
#     tags=jieba.analyse.extract_tags(cleaned_comment, topK = 50, withWeight = False, allowPOS = ())
#     if stopwords:
#         words = [word for word in jieba.cut(cleaned_comment) if word not in stopwords]
#     else:
#         words = [word in jieba.cut(cleaned_comment)]
    words = jieba.cut(cleaned_comment)
   
    wordcloud = WordCloud('/home/xuzuoyang/Downloads/simsun.ttf', stopwords=stopwords).generate(' '.join(words))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
